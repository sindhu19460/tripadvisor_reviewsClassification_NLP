# %%
import pandas as pd

# %%
import nltk
from nltk.stem import LancasterStemmer, WordNetLemmatizer, PorterStemmer
from nltk import FreqDist
nltk.download('stopwords') # run this one time
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
import matplotlib as mpl
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud
nltk.download('wordnet')
from nltk.util import ngrams
from nltk.corpus import stopwords, wordnet

hotel = pd.read_csv("Hard_Rock_New_Review.csv", engine='python')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # exploratory data analysis

# %%
print(hotel.describe().transpose())
# Out:
#              count        mean         std   min     25%     50%      75%  \
# Unnamed: 0  3062.0  1530.50000  884.067588   0.0  765.25  1530.5  2295.75
# Rating      3062.0    41.67211    9.409880  10.0   40.00    40.0    50.00
#
#                max
# Unnamed: 0  3061.0
# Rating        50.0

# %%
hotel.head()
# Out:
#    Unnamed: 0              Date  Rating                              Title  \
# 0           0     17 March 2020      50                     It's not noisy
# 1           1     13 March 2020      40  Good burger and unique atmosphere
# 2           2  24 February 2020      30           !00 people for breakfast
# 3           3  23 February 2020      50             Combo Platter For Two!
# 4           4  12 February 2020      50            Last drinks before home
#
#                                               Review
# 0  It may sound noisy initially but if you find a...
# 1  I had a very good burger here. The atmosphere ...
# 2  We pre arranged breakfast for 100 people and t...
# 3  Nice Decor! Share a platter: crumbed chicken, ...
# 4  This is a great hard rock I've never been to a...

# %%
hotel[hotel['Review'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Rating, Title, Review]
# Index: []

# %%
hotel['Rating'] = hotel['Rating'].replace({10:'VERY NEGATIVE',20:'NEGATIVE',30:'NEUTRAL',40:'POSITIVE',50:'VERY POSITIVE'})

# %% [markdown]
# # function to plot most frequent terms

# %%
def freq_words(x, terms = 30):
  all_words = ' '.join([text for text in x])
  all_words = all_words.split()

  fdist = FreqDist(all_words)
  words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})

  # selecting top 20 most frequent words
  d = words_df.nlargest(columns="count", n = terms) 
  plt.figure(figsize=(20,5))
  ax = sns.barplot(data=d, x= "word", y = "count")
  ax.set(ylabel = 'Count')
  plt.show()

# %%
freq_words(hotel['Review'])

# %% [markdown]
# # lenghth of review

# %%
hotel_1 = hotel.copy()
hotel_1["Review"] = hotel_1["Review"].apply(str)

# %%
hotel_1["REVIEWS LENGTH"] = hotel_1["Review"].apply(lambda w : len(re.findall(r'\w+', w)))

# %%
hotel_1.sample(20)
# Out:
#       Unnamed: 0               Date         Rating  \
# 1744        1744      29 March 2018       POSITIVE
# 490          490    16 October 2016  VERY POSITIVE
# 612          612       10 June 2016  VERY POSITIVE
# 1425        1425       16 June 2012       POSITIVE
# 565          565       29 July 2016       POSITIVE
# 1721        1721        17 May 2018        NEUTRAL
# 656          656      23 April 2016        NEUTRAL
# 2756        2756   20 December 2013  VERY POSITIVE
# 1233        1233  19 September 2013       POSITIVE
# 664          664       7 April 2016       NEGATIVE
# 2701        2701        21 May 2014  VERY POSITIVE
# 2527        2527         8 May 2015  VERY POSITIVE
# 2966        2966       20 June 2012  VERY POSITIVE
# 2535        2535       8 April 2015       POSITIVE
# 2277        2277    14 January 2016        NEUTRAL
# 1783        1783     4 January 2018       POSITIVE
# 2412        2412  13 September 2015       POSITIVE
# 3053        3053  12 September 2011  VERY POSITIVE
# 1399        1399       25 July 2012        NEUTRAL
# 444          444    7 December 2016        NEUTRAL
#
#                                                   Title  \
# 1744                                     Fun experience
# 490                                          Great food
# 612                            Fantastic Hard Rock Cafe
# 1425                                               like
# 565                        Not just any chain resturant
# 1721                Met our needs , but nothing special
# 656                        Breakfast buffet was average
# 2756                              Re-Visited, delicious
# 1233                          Like all other Hard Rocks
# 664                                       Not Very Good
# 2701                        Another good Hard Rock Cafe
# 2527                                     Food was great
# 2966                             Great breakfast buffet
# 2535                                  Always a favorite
# 2277  Breakfast was tasty but it took AGES to arrive...
# 1783                            Pretty good for a chain
# 2412  Just typical Hard Rock really, you could have ...
# 3053                                Amazing restaurant!
# 1399                                                 ok
# 444     Not the best Hard Rock Cafe that I have visited
#
#                                                  Review  REVIEWS LENGTH
# 1744  Service and experience were fun! Worth the vis...              29
# 490   My daughter and I ate here on our first New Yo...              41
# 612   Best Hard Rock I have been too. Great atmosphe...              26
# 1425  I love going into this place for a look around...              17
# 565   The staff and food were both better than expec...              26
# 1721  Our daughter has allergies and the could accom...              23
# 656   Not the best food selection or quality, but go...              26
# 2756  Once again the Hard Rock NYC did not disappoin...              23
# 1233  If you know what a Hard Rock CafÃ© is like, th...              46
# 664   To be honest i really disliked this restaurant...              24
# 2701  Nothing relevant to highlight this restaurant ...              26
# 2527  Nice atmosphere. Great menu copious amount of ...              34
# 2966  We were surprised how few people eat breakfast...              35
# 2535  Hard Rock Cafe is always a favorite, because i...              44
# 2277  Me and my boyfriend had breakfast here, I had ...              44
# 1783  Never my 1st choice, however after the hockey ...              44
# 2412  As with every Hard Rock CafÃ© I have ever been...              41
# 3053  HRC is great in every city, but this one has i...              24
# 1399  was ok staff wasnt the friendlist food was jus...              29
# 444   Visited this restaurant on my recent trip to N...              32

# %%
hotel_1["REVIEWS LENGTH"].describe()
# Out:
# count    3062.000000
# mean       31.238733
# std         8.714959
# min         4.000000
# 25%        24.000000
# 50%        31.000000
# 75%        38.000000
# max        97.000000
# Name: REVIEWS LENGTH, dtype: float64

# %%
hotel_1["REVIEWS LENGTH"].sum() # TOTAL NUMBERS OF WORDS IN REVIEWS IS 95653
# Out:
# 95653

# %%
hotel_1["Review"].describe()
# Out:
# count                                                  3062
# unique                                                 1543
# top       This Hard Rock is as good as any other Hard Ro...
# freq                                                      3
# Name: Review, dtype: object

# %%
#plt.figure()
sns.boxplot(data = hotel_1, x = "REVIEWS LENGTH")
plt.xlabel('Number of Words')
plt.title('Review Length, Including Stop Words')
plt.show()

# %%
sns.distplot(hotel_1["REVIEWS LENGTH"], kde = False)
plt.xlabel('Distribution of Review Length')
plt.title('Review Length, Including Stop Words')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x_rating = hotel.Rating.value_counts()
y_rating = x_rating.sort_index()
plt.figure(figsize=(50,30))
sns.barplot(x_rating.index, x_rating.values, alpha=0.8)
plt.title("Rating Distribution", fontsize=50)
plt.ylabel('Frequency', fontsize=50)
plt.yticks(fontsize=40)
plt.xlabel('Employee Ratings', fontsize=50)
plt.xticks(fontsize=40)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(30,10))
plt.title('Percentage of Ratings', fontsize=20)
hotel.Rating.value_counts().plot(kind='pie', labels=['VERY POSITIVE','POSITIVE','NETURAL','NEGATIVE','VERY NEGATIVE'],
                              wedgeprops=dict(width=.7), autopct='%1.0f%%', startangle= -20, 
                              textprops={'fontsize': 15})
plt.ylabel("Rating",fontsize=40)
plt.show()

# %%
date=hotel['Date']
hotel.date = date.astype("datetime64")
hotel.groupby(hotel.date.dt.month).count().plot(kind="bar")
# Out:
# <ipython-input-19-1aaec2ca30fa>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   hotel.date = date.astype("datetime64")
# <AxesSubplot:xlabel='Date'>

# %%
hotel.drop(['Unnamed: 0','Date','Rating','Title'],axis=1,inplace=True)

# %%
hotel.head()
# Out:
#                                               Review
# 0  It may sound noisy initially but if you find a...
# 1  I had a very good burger here. The atmosphere ...
# 2  We pre arranged breakfast for 100 people and t...
# 3  Nice Decor! Share a platter: crumbed chicken, ...
# 4  This is a great hard rock I've never been to a...

# %% [markdown]
# # cleaning the text

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
hotel_df = hotel.copy()
stop_words = stopwords.words("english")

# %%
def clean(s):
    s = s.lower()                   #Converting to lower case
    s = re.sub(r'[^\w\s]', ' ', s)  #Removing punctuation
    s = re.sub(r'[\d+]', ' ', s)    #Removing Numbers
    s = s.strip()                   #Removing trailing spaces
    s = re.sub(' +', ' ', s)        #Removing extra whitespaces
    return s

# %%
hotel_df["Review"] = hotel_df["Review"].apply(lambda x: clean(x))

# %%
hotel_df.head(20)
# Out:
#                                                Review
# 0   it may sound noisy initially but if you find a...
# 1   i had a very good burger here the atmosphere i...
# 2   we pre arranged breakfast for people and they ...
# 3   nice decor share a platter crumbed chicken spr...
# 4   this is a great hard rock i ve never been to a...
# 5   we booked online beforehand as i went a few ye...
# 6   not dissapionted at all it does what it says v...
# 7   we all had the legendary burger and it was del...
# 8   had dinner in here with my daughter and grandd...
# 9   you have to go in time to get a table but it s...
# 10  a very good meal of fajitas ribs and salads th...
# 11  quick easy friendly service easy place to get ...
# 12  i ve been to lots of hard rock cafes round the...
# 13  really friendly staff food was well nice and p...
# 14  excellent place to visit fun atmosphere food g...
# 15  rude bar attendant felt very rushed waitress s...
# 16  what an overrated venue the staff were horribl...
# 17  place was fully packed we end up ordering our ...
# 18  we attended the first hard rock cafe gala for ...
# 19  ate breakfast buffet with daughter while in ne...

# %% [markdown]
# # stopwards

# %%
hotel_df["Review"] = hotel_df["Review"].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))

# %%
hotel_df["Review"][2]
# Out:
# 'pre arranged breakfast people opened us normal opening time standard usa breakfast nothing special good enough us long day new york'

# %% [markdown]
# # stemming

# %%
st = PorterStemmer()
hotel_df['Review'] = hotel_df['Review'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
hotel_df['Review']
# Out:
# 0       may sound noisi initi find good place bar nois...
# 1       good burger atmospher uniqu expect hard rock m...
# 2       pre arrang breakfast peopl open us normal open...
# 3       nice decor share platter crumb chicken spring ...
# 4       great hard rock never bad countri favourit far...
#                               ...
# 3057    great food good atmospher realli nice place su...
# 3058    wait hour half tabl sat cold room away main ro...
# 3059    new york style make hard rock best around worl...
# 3060    fun place eat food good seve quickli mani rock...
# 3061    food great ident menu everi locat server check...
# Name: Review, Length: 3062, dtype: object

# %% [markdown]
# # world cloud

# %%
reviews = pd.Series(hotel_df["Review"].tolist()).astype(str)
plt.figure(figsize = (9, 9))
rev_wcloud_all = WordCloud(width = 900, height = 900, colormap = 'plasma', max_words = 150).generate(''.join(reviews))
plt.imshow(rev_wcloud_all)
plt.tight_layout(pad = 0.2)
plt.axis('off')
plt.show()

# %%
#pip install textblob      

import textblob            
from textblob import TextBlob
# Out:
# Requirement already satisfied: textblob in c:\programdata\anaconda3\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\lib\site-packages (from textblob) (3.5)
# Requirement already satisfied: regex in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2020.10.15)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (0.17.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.50.2)

# %% [markdown]
# # TOKENIZATION
#
# #### Tokenization is splitting a body of text into smaller units, such as individual words or terms. Each of these smaller units are called tokens

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer

# %%
hotel_df['Review']=hotel_df['Review'].apply(str)

# %%
tokenizer = RegexpTokenizer(r'\w+')
hotel_df["Reviews_Token"] = hotel_df["Review"].apply(lambda x: tokenizer.tokenize(x))

# %% [markdown]
# # LEMMATIZATION
#
# ##### Lemmatization extracts the root of the word. For example, from the word "driving', "drive" is extracted. Unlike stemming, lemmatization understands the context and provides the root words rather than simply removing the suffix or prefix of the word.

# %%
lemm = WordNetLemmatizer()

# %%
def to_wordnet(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None

def lemm_text(text):
    nltk_tagged = nltk.pos_tag(text)
    # Result = (text, pos_tag)
    wordnet_tagged = map(lambda x: (x[0], to_wordnet(x[1])), nltk_tagged)
    lemm_sentence = []
    for word, tag in wordnet_tagged:
        if tag is None:
            lemm_sentence.append(word)
        else:
            lemm_sentence.append(lemm.lemmatize(word, tag))
    return lemm_sentence

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
hotel_df["Reviews_Lemm"] = hotel_df["Reviews_Token"].apply(lambda x: lemm_text(x))

# %%
hotel_df[["Reviews_Token", "Reviews_Lemm"]].sample(14)
# Out:
#                                           Reviews_Token  \
# 1364  [everi, place, go, make, sure, goto, hard, roc...
# 2411  [good, rememb, last, time, feel, satisfi, left...
# 164   [sticki, tablecloth, atmospher, veggi, burger,...
# 834   [love, place, memorabilia, staff, food, bought...
# 2214  [busi, menu, lot, option, spent, hour, need, u...
# 2477  [great, dinner, hard, rock, lip, sync, one, wa...
# 984   [big, well, round, menu, great, drink, select,...
# 1970  [like, mini, music, museum, good, dinner, foun...
# 969   [great, place, love, staff, food, great, photo...
# 1247  [food, amaz, great, atmospher, friendli, staff...
# 720   [allan, rock, went, drink, appet, allan, super...
# 2535  [hard, rock, cafe, alway, favorit, great, valu...
# 2847  [catch, right, time, queue, pm, around, pm, fa...
# 1053  [atmospher, second, none, food, averag, honest...
#
#                                            Reviews_Lemm
# 1364  [everi, place, go, make, sure, goto, hard, roc...
# 2411  [good, rememb, last, time, feel, satisfi, leav...
# 164   [sticki, tablecloth, atmospher, veggi, burger,...
# 834   [love, place, memorabilia, staff, food, buy, q...
# 2214  [busi, menu, lot, option, spend, hour, need, u...
# 2477  [great, dinner, hard, rock, lip, sync, one, wa...
# 984   [big, well, round, menu, great, drink, select,...
# 1970  [like, mini, music, museum, good, dinner, find...
# 969   [great, place, love, staff, food, great, photo...
# 1247  [food, amaz, great, atmospher, friendli, staff...
# 720   [allan, rock, go, drink, appet, allan, super, ...
# 2535  [hard, rock, cafe, alway, favorit, great, valu...
# 2847  [catch, right, time, queue, pm, around, pm, fa...
# 1053  [atmospher, second, none, food, averag, honest...

# %% [markdown]
# # most common words

# %%
import itertools
import collections

# %%
review_list = list(itertools.chain.from_iterable(hotel_df['Reviews_Lemm']))
rev_word_freq = collections.Counter(review_list)

word_freq_DF = pd.DataFrame(rev_word_freq.most_common(15), columns=['Words', 'Count'])
word_freq_DF
# Out:
#         Words  Count
# 0        food   2189
# 1        good   1641
# 2       great   1521
# 3        rock   1142
# 4      servic   1140
# 5        hard   1000
# 6        time    752
# 7       place    684
# 8          go    667
# 9       staff    600
# 10  atmospher    598
# 11      visit    581
# 12       wait    512
# 13       cafe    451
# 14       love    438

# %%
sns.barplot(data = word_freq_DF, x = "Words", y = "Count")
plt.ylabel("Frequency")
plt.xticks(rotation = 90)
plt.title("15 Most Frequent Words in Amazon Reviews")
plt.show()

# %% [markdown]
# # SENTIMENT ANALYSIS

# %%
hotel_df["Sentiment_TextBlob"] = hotel_df["Review"].apply(lambda x: TextBlob(x).sentiment[0])

# %%
hotel_df[["Review", "Sentiment_TextBlob"]].head(10)
# Out:
#                                               Review  Sentiment_TextBlob
# 0  may sound noisi initi find good place bar nois...            0.441667
# 1  good burger atmospher uniqu expect hard rock m...            0.204167
# 2  pre arrang breakfast peopl open us normal open...            0.143723
# 3  nice decor share platter crumb chicken spring ...            0.050000
# 4  great hard rock never bad countri favourit far...            0.443056
# 5  book onlin beforehand went year ago quit wait ...            0.483333
# 6  dissapiont say nice food drink servic well loo...            0.154167
# 7  legendari burger delici servic friendli good s...            0.566667
# 8  dinner daughter granddaught busi food fast per...            0.200000
# 9  go time get tabl worth special hamburg delici ...            0.452381

# %%
from nltk.stem import WordNetLemmatizer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
senti = SentimentIntensityAnalyzer()
hotel_df["Sentiment_VADER"] = hotel_df["Review"].apply(lambda x: senti.polarity_scores(x)['compound'])

# %%
hotel_df[["Review", "Sentiment_VADER", "Sentiment_TextBlob"]].sample(15)
# Out:
#                                                  Review  Sentiment_VADER  \
# 1017  one hard rock pretti much enjoy rock memorabil...           0.6908
# 620   burger wife steak food realli good steak cook ...           0.8625
# 2834  food good servic averag dã cor typic hard rock...           0.5267
# 1189  go hard rock cafe expect level commerci servic...           0.6908
# 796   visit new york alway get souvenir hard rock es...           0.2911
# 151   visit hard rock cafe januari chaotic good musi...           0.6597
# 1044  hard rock cafe food locat menu might bit diffe...           0.3612
# 2718  one differ other bad thing food great servic g...           0.4767
# 2708  like rock n roll realli enjoy place good music...           0.8885
# 3041  shop restaur everyth els time squar big crowd ...           0.0000
# 2234  sure restaur serv better meal got actual atmos...           0.1779
# 903   went dinner nice wait bit noth terribl food qu...           0.6908
# 524   excel food friendli staff great place visit pl...           0.7964
# 356   well worth visit memorabilia show worth see al...           0.8750
# 1420  best hardrock orlando best servic good food av...           0.8481
#
#       Sentiment_TextBlob
# 1017            0.302778
# 620             0.850000
# 2834            0.181667
# 1189            0.252083
# 796             0.036174
# 151             0.381667
# 1044            0.204167
# 2718            0.022222
# 2708            0.600000
# 3041            0.000000
# 2234            0.075000
# 903             0.500000
# 524             0.500000
# 356             0.400000
# 1420            0.575000

# %%
hotel_df[["Review", "Sentiment_VADER"]][hotel_df["Sentiment_VADER"] < -0.1]
# Out:
#                                                  Review  Sentiment_VADER
# 12    lot hard rock cafe round world disappoint serv...          -0.7783
# 15    rude bar attend felt rush waitress seem consta...          -0.8176
# 49    daughter friend took limo citi would miss hang...          -0.4019
# 70    stay away get pretzel order peopl end five dif...          -0.6249
# 76    came last meal fli back u k fantast place musi...          -0.4215
# ...                                                 ...              ...
# 2924  want experi hard rock nyc hand drink overal ba...          -0.4767
# 2942  restaur typic hard rock server pin man awesom ...          -0.1027
# 2958  seen one seen much type stop travel famili go ...          -0.2960
# 2968  crazi branch restaur pleas visit hard rock com...          -0.3818
# 2996  first time eat hard rock cafe went pm wait hou...          -0.1027
#
# [173 rows x 2 columns]

# %%
sns.distplot(hotel_df["Sentiment_VADER"], kde = False, label = "VADER")
sns.distplot(hotel_df["Sentiment_TextBlob"], kde = False, label = "TextBlob")
plt.xlabel("Sentiment Polarity Scores")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data = pd.melt(hotel_df[["Sentiment_VADER", "Sentiment_TextBlob"]]), x = "value", y = "variable")
plt.xlabel("Sentiment Polarity Scores")
plt.ylabel("Type of Sentiment Analysis")
plt.show()

# %% [markdown]
# # MOST POSITIVE REVIEWS - TEXTBLOB

# %%
DF_Pos_TB = hotel_df[["Review","Reviews_Lemm","Sentiment_TextBlob"]][hotel_df["Sentiment_TextBlob"] == hotel_df["Sentiment_TextBlob"].max()]

# %%
DF_Pos_TB
# Out:
#                                                  Review  \
# 239   wait hour food wonder staf best mind wait cust...
# 295   best food best drink superb atmospher would de...
# 399   rock cafe best one world beautif shin best dri...
# 504   food superb staff friendli bartend serv chanta...
# 999   atmospher rocki relax theme perfect day shop s...
# 1784  wait hour food wonder staf best mind wait cust...
# 1840  best food best drink superb atmospher would de...
# 1944  rock cafe best one world beautif shin best dri...
# 2049  food superb staff friendli bartend serv chanta...
# 2544  atmospher rocki relax theme perfect day shop s...
#
#                                            Reviews_Lemm  Sentiment_TextBlob
# 239   [wait, hour, food, wonder, staf, best, mind, w...                 1.0
# 295   [best, food, best, drink, superb, atmospher, w...                 1.0
# 399   [rock, cafe, best, one, world, beautif, shin, ...                 1.0
# 504   [food, superb, staff, friendli, bartend, serv,...                 1.0
# 999   [atmospher, rocki, relax, theme, perfect, day,...                 1.0
# 1784  [wait, hour, food, wonder, staf, best, mind, w...                 1.0
# 1840  [best, food, best, drink, superb, atmospher, w...                 1.0
# 1944  [rock, cafe, best, one, world, beautif, shin, ...                 1.0
# 2049  [food, superb, staff, friendli, bartend, serv,...                 1.0
# 2544  [atmospher, rocki, relax, theme, perfect, day,...                 1.0

# %% [markdown]
# # WORDCLOUD OF THE MOST POSITIVE REVIEWS - TEXTBLOB

# %%
# Word Cloud from the most postive reviews from TextBlob

plt.figure(figsize = (9, 9))
wcloud_Pos_TB = WordCloud(width = 900, height = 900, colormap = 'plasma', max_words = 150).generate(' '.join(pd.Series(DF_Pos_TB["Review"].tolist()).astype(str)))
plt.imshow(wcloud_Pos_TB)
plt.tight_layout(pad = 0.2)
plt.axis('off')
plt.show()

# %% [markdown]
# # MOST POSTIVE REVIEWS - VADER

# %%
hotel_df[["Review","Reviews_Lemm","Sentiment_VADER"]][hotel_df["Sentiment_VADER"] == hotel_df["Sentiment_VADER"].max()]
# Out:
#                                                  Review  \
# 673   great food great staff great servic book advan...
# 2218  great food great staff great servic book advan...
#
#                                            Reviews_Lemm  Sentiment_VADER
# 673   [great, food, great, staff, great, servic, boo...           0.9806
# 2218  [great, food, great, staff, great, servic, boo...           0.9806

# %%
DF_Pos_VADER = hotel_df[["Review","Reviews_Lemm","Sentiment_VADER"]][hotel_df["Sentiment_VADER"] > 0.8]

# %%
DF_Pos_VADER
# Out:
#                                                  Review  \
# 0     may sound noisi initi find good place bar nois...
# 3     nice decor share platter crumb chicken spring ...
# 4     great hard rock never bad countri favourit far...
# 7     legendari burger delici servic friendli good s...
# 9     go time get tabl worth special hamburg delici ...
# ...                                                 ...
# 3050  go hard rock look michellin star food american...
# 3053  hrc great everi citi one incred thing like bea...
# 3056  went watch super bowl big screen great food gr...
# 3057  great food good atmospher realli nice place su...
# 3059  new york style make hard rock best around worl...
#
#                                            Reviews_Lemm  Sentiment_VADER
# 0     [may, sound, noisi, initi, find, good, place, ...           0.8720
# 3     [nice, decor, share, platter, crumb, chicken, ...           0.8442
# 4     [great, hard, rock, never, bad, countri, favou...           0.9377
# 7     [legendari, burger, delici, servic, friendli, ...           0.9186
# 9     [go, time, get, tabl, worth, special, hamburg,...           0.8225
# ...                                                 ...              ...
# 3050  [go, hard, rock, look, michellin, star, food, ...           0.9485
# 3053  [hrc, great, everi, citi, one, incred, thing, ...           0.8934
# 3056  [go, watch, super, bowl, big, screen, great, f...           0.8689
# 3057  [great, food, good, atmospher, realli, nice, p...           0.9136
# 3059  [new, york, style, make, hard, rock, best, aro...           0.8402
#
# [1367 rows x 3 columns]

# %% [markdown]
# # WORDCLOUD OF THE MOST POSTIVE REVIEWS - VADER

# %%
plt.figure(figsize = (9, 9))
wcloud_Pos_VADER = WordCloud(width = 900, height = 900, colormap = 'plasma', max_words = 150).generate(' '.join(pd.Series(DF_Pos_VADER["Review"].tolist()).astype(str)))
plt.imshow(wcloud_Pos_VADER)
plt.tight_layout(pad = 0.2)
plt.axis('off')
plt.show()

# %% [markdown]
# # MOST NEGATIVE REVIEWS - TEXTBLOB

# %%
hotel_df[["Review","Reviews_Lemm","Sentiment_TextBlob"]][hotel_df["Sentiment_TextBlob"] == hotel_df["Sentiment_TextBlob"].min()]
# Out:
#                                                  Review  \
# 70    stay away get pretzel order peopl end five dif...
# 1615  stay away get pretzel order peopl end five dif...
#
#                                            Reviews_Lemm  Sentiment_TextBlob
# 70    [stay, away, get, pretzel, order, peopl, end, ...                -1.0
# 1615  [stay, away, get, pretzel, order, peopl, end, ...                -1.0

# %%
DF_Neg_TB = hotel_df[["Review","Reviews_Lemm","Sentiment_TextBlob"]][hotel_df["Sentiment_TextBlob"] < -0.0]

# %%
DF_Neg_TB
# Out:
#                                                  Review  \
# 12    lot hard rock cafe round world disappoint serv...
# 15    rude bar attend felt rush waitress seem consta...
# 23    alway take hrc son birthday like busi vibe sur...
# 39    visit cafe everi citi ritual hustl bustl broad...
# 68    music fan must visit hard rock cafe must went ...
# ...                                                 ...
# 2996  first time eat hard rock cafe went pm wait hou...
# 3020  pleas favor go someplac els hard rock found ar...
# 3036  went middl afternoon least line major plu six ...
# 3049  standard hard rock fayr friendli help staff li...
# 3058  wait hour half tabl sat cold room away main ro...
#
#                                            Reviews_Lemm  Sentiment_TextBlob
# 12    [lot, hard, rock, cafe, round, world, disappoi...           -0.205556
# 15    [rude, bar, attend, felt, rush, waitress, seem...           -0.418333
# 23    [alway, take, hrc, son, birthday, like, busi, ...           -0.066667
# 39    [visit, cafe, everi, citi, ritual, hustl, bust...           -0.250000
# 68    [music, fan, must, visit, hard, rock, cafe, mu...           -0.291667
# ...                                                 ...                 ...
# 2996  [first, time, eat, hard, rock, cafe, go, pm, w...           -0.069444
# 3020  [plea, favor, go, someplac, el, hard, rock, fi...           -0.077652
# 3036  [go, middl, afternoon, least, line, major, plu...           -0.118750
# 3049  [standard, hard, rock, fayr, friendli, help, s...           -0.194444
# 3058  [wait, hour, half, tabl, sit, cold, room, away...           -0.240000
#
# [253 rows x 3 columns]

# %% [markdown]
# # WORDCLOUD OF THE MOST NEGATIVE REVIEWS - TEXTBLOB

# %%
# Word Cloud of the most negative reviews from TextBlob

plt.figure(figsize = (9, 9))
wcloud_Neg_TB = WordCloud(width = 900, height = 900, colormap = 'plasma', max_words = 150).generate(' '.join(pd.Series(DF_Neg_TB["Review"].tolist()).astype(str)))
plt.imshow(wcloud_Neg_TB)
plt.tight_layout(pad = 0.2)
plt.axis('off')
plt.show()

# %% [markdown]
# # MOST NEGATIVE REVIEWS - VADER

# %%
hotel_df[["Review","Reviews_Lemm","Sentiment_VADER"]][hotel_df["Sentiment_VADER"] == hotel_df["Sentiment_VADER"].min()]
# Out:
#                                                  Review  \
# 472   took min take first order got secon round drin...
# 2017  took min take first order got secon round drin...
#
#                                            Reviews_Lemm  Sentiment_VADER
# 472   [take, min, take, first, order, get, secon, ro...          -0.9337
# 2017  [take, min, take, first, order, get, secon, ro...          -0.9337

# %%
DF_Neg_VADER = hotel_df[["Review","Reviews_Lemm","Sentiment_VADER"]][hotel_df["Sentiment_VADER"] < -0.1]

# %%
DF_Neg_VADER
# Out:
#                                                  Review  \
# 12    lot hard rock cafe round world disappoint serv...
# 15    rude bar attend felt rush waitress seem consta...
# 49    daughter friend took limo citi would miss hang...
# 70    stay away get pretzel order peopl end five dif...
# 76    came last meal fli back u k fantast place musi...
# ...                                                 ...
# 2924  want experi hard rock nyc hand drink overal ba...
# 2942  restaur typic hard rock server pin man awesom ...
# 2958  seen one seen much type stop travel famili go ...
# 2968  crazi branch restaur pleas visit hard rock com...
# 2996  first time eat hard rock cafe went pm wait hou...
#
#                                            Reviews_Lemm  Sentiment_VADER
# 12    [lot, hard, rock, cafe, round, world, disappoi...          -0.7783
# 15    [rude, bar, attend, felt, rush, waitress, seem...          -0.8176
# 49    [daughter, friend, take, limo, citi, would, mi...          -0.4019
# 70    [stay, away, get, pretzel, order, peopl, end, ...          -0.6249
# 76    [come, last, meal, fli, back, u, k, fantast, p...          -0.4215
# ...                                                 ...              ...
# 2924  [want, experi, hard, rock, nyc, hand, drink, o...          -0.4767
# 2942  [restaur, typic, hard, rock, server, pin, man,...          -0.1027
# 2958  [see, one, see, much, type, stop, travel, fami...          -0.2960
# 2968  [crazi, branch, restaur, pleas, visit, hard, r...          -0.3818
# 2996  [first, time, eat, hard, rock, cafe, go, pm, w...          -0.1027
#
# [173 rows x 3 columns]

# %%
plt.figure(figsize = (9, 9))
wcloud_Neg_VADER = WordCloud(width = 900, height = 900, colormap = 'plasma', max_words = 150).generate(' '.join(pd.Series(DF_Neg_VADER["Review"].tolist()).astype(str)))
plt.imshow(wcloud_Neg_VADER)
plt.tight_layout(pad = 0.2)
plt.axis('off')
plt.show()

# %% [markdown]
# # BI-GRAMS

# %%
hotel_df["Bigrams"] = hotel_df["Reviews_Lemm"].apply(lambda x: list(ngrams(x, 2)))

# %%
hotel_df
# Out:
#                                                  Review  \
# 0     may sound noisi initi find good place bar nois...
# 1     good burger atmospher uniqu expect hard rock m...
# 2     pre arrang breakfast peopl open us normal open...
# 3     nice decor share platter crumb chicken spring ...
# 4     great hard rock never bad countri favourit far...
# ...                                                 ...
# 3057  great food good atmospher realli nice place su...
# 3058  wait hour half tabl sat cold room away main ro...
# 3059  new york style make hard rock best around worl...
# 3060  fun place eat food good seve quickli mani rock...
# 3061  food great ident menu everi locat server check...
#
#                                           Reviews_Token  \
# 0     [may, sound, noisi, initi, find, good, place, ...
# 1     [good, burger, atmospher, uniqu, expect, hard,...
# 2     [pre, arrang, breakfast, peopl, open, us, norm...
# 3     [nice, decor, share, platter, crumb, chicken, ...
# 4     [great, hard, rock, never, bad, countri, favou...
# ...                                                 ...
# 3057  [great, food, good, atmospher, realli, nice, p...
# 3058  [wait, hour, half, tabl, sat, cold, room, away...
# 3059  [new, york, style, make, hard, rock, best, aro...
# 3060  [fun, place, eat, food, good, seve, quickli, m...
# 3061  [food, great, ident, menu, everi, locat, serve...
#
#                                            Reviews_Lemm  Sentiment_TextBlob  \
# 0     [may, sound, noisi, initi, find, good, place, ...            0.441667
# 1     [good, burger, atmospher, uniqu, expect, hard,...            0.204167
# 2     [pre, arrang, breakfast, peopl, open, us, norm...            0.143723
# 3     [nice, decor, share, platter, crumb, chicken, ...            0.050000
# 4     [great, hard, rock, never, bad, countri, favou...            0.443056
# ...                                                 ...                 ...
# 3057  [great, food, good, atmospher, realli, nice, p...            0.700000
# 3058  [wait, hour, half, tabl, sit, cold, room, away...           -0.240000
# 3059  [new, york, style, make, hard, rock, best, aro...            0.388939
# 3060  [fun, place, eat, food, good, seve, quickli, m...            0.500000
# 3061  [food, great, ident, menu, everi, locat, serve...            0.450000
#
#       Sentiment_VADER                                            Bigrams
# 0              0.8720  [(may, sound), (sound, noisi), (noisi, initi),...
# 1              0.3612  [(good, burger), (burger, atmospher), (atmosph...
# 2              0.6808  [(pre, arrang), (arrang, breakfast), (breakfas...
# 3              0.8442  [(nice, decor), (decor, share), (share, platte...
# 4              0.9377  [(great, hard), (hard, rock), (rock, never), (...
# ...               ...                                                ...
# 3057           0.9136  [(great, food), (food, good), (good, atmospher...
# 3058           0.0000  [(wait, hour), (hour, half), (half, tabl), (ta...
# 3059           0.8402  [(new, york), (york, style), (style, make), (m...
# 3060           0.7351  [(fun, place), (place, eat), (eat, food), (foo...
# 3061           0.6249  [(food, great), (great, ident), (ident, menu),...
#
# [3062 rows x 6 columns]

# %%
bigrams_list = list(itertools.chain.from_iterable(hotel_df['Bigrams']))
bigrams_freq = collections.Counter(bigrams_list)

bigrams_freq_DF = pd.DataFrame(bigrams_freq.most_common(30), columns=['Bigrams', 'Count'])
bigrams_freq_DF
# Out:
#                Bigrams  Count
# 0         (hard, rock)    976
# 1         (rock, cafe)    413
# 2        (time, squar)    359
# 3         (food, good)    322
# 4         (good, food)    253
# 5          (new, york)    242
# 6        (food, great)    207
# 7        (great, food)    188
# 8       (good, servic)    164
# 9   (great, atmospher)    160
# 10     (great, servic)    153
# 11      (servic, good)    149
# 12   (staff, friendli)    112
# 13     (servic, great)    111
# 14      (great, place)    100
# 15      (servic, food)     90
# 16      (food, servic)     84
# 17     (reason, price)     81
# 18      (worth, visit)     80
# 19       (visit, hard)     79
# 20   (friendli, staff)     76
# 21       (food, drink)     74
# 22      (realli, good)     70
# 23      (food, averag)     70
# 24          (food, ok)     68
# 25  (atmospher, great)     68
# 26          (go, back)     64
# 27       (good, music)     60
# 28       (good, place)     54
# 29          (go, hard)     52

# %%
plt.figure(figsize = (10,7))
sns.barplot(data = bigrams_freq_DF, x = "Count", y = "Bigrams")
plt.xlabel("Frequency")
plt.ylabel("Bigrams")
plt.title("30 Most Frequent Bigrams in TripAdvisore Reviews")
plt.show()

# %% [markdown]
# # TRI-GRAMS

# %%
hotel_df["Trigrams"] = hotel_df["Reviews_Lemm"].apply(lambda x: list(ngrams(x, 3)))

# %%
hotel_df
# Out:
#                                                  Review  \
# 0     may sound noisi initi find good place bar nois...
# 1     good burger atmospher uniqu expect hard rock m...
# 2     pre arrang breakfast peopl open us normal open...
# 3     nice decor share platter crumb chicken spring ...
# 4     great hard rock never bad countri favourit far...
# ...                                                 ...
# 3057  great food good atmospher realli nice place su...
# 3058  wait hour half tabl sat cold room away main ro...
# 3059  new york style make hard rock best around worl...
# 3060  fun place eat food good seve quickli mani rock...
# 3061  food great ident menu everi locat server check...
#
#                                           Reviews_Token  \
# 0     [may, sound, noisi, initi, find, good, place, ...
# 1     [good, burger, atmospher, uniqu, expect, hard,...
# 2     [pre, arrang, breakfast, peopl, open, us, norm...
# 3     [nice, decor, share, platter, crumb, chicken, ...
# 4     [great, hard, rock, never, bad, countri, favou...
# ...                                                 ...
# 3057  [great, food, good, atmospher, realli, nice, p...
# 3058  [wait, hour, half, tabl, sat, cold, room, away...
# 3059  [new, york, style, make, hard, rock, best, aro...
# 3060  [fun, place, eat, food, good, seve, quickli, m...
# 3061  [food, great, ident, menu, everi, locat, serve...
#
#                                            Reviews_Lemm  Sentiment_TextBlob  \
# 0     [may, sound, noisi, initi, find, good, place, ...            0.441667
# 1     [good, burger, atmospher, uniqu, expect, hard,...            0.204167
# 2     [pre, arrang, breakfast, peopl, open, us, norm...            0.143723
# 3     [nice, decor, share, platter, crumb, chicken, ...            0.050000
# 4     [great, hard, rock, never, bad, countri, favou...            0.443056
# ...                                                 ...                 ...
# 3057  [great, food, good, atmospher, realli, nice, p...            0.700000
# 3058  [wait, hour, half, tabl, sit, cold, room, away...           -0.240000
# 3059  [new, york, style, make, hard, rock, best, aro...            0.388939
# 3060  [fun, place, eat, food, good, seve, quickli, m...            0.500000
# 3061  [food, great, ident, menu, everi, locat, serve...            0.450000
#
#       Sentiment_VADER                                            Bigrams  \
# 0              0.8720  [(may, sound), (sound, noisi), (noisi, initi),...
# 1              0.3612  [(good, burger), (burger, atmospher), (atmosph...
# 2              0.6808  [(pre, arrang), (arrang, breakfast), (breakfas...
# 3              0.8442  [(nice, decor), (decor, share), (share, platte...
# 4              0.9377  [(great, hard), (hard, rock), (rock, never), (...
# ...               ...                                                ...
# 3057           0.9136  [(great, food), (food, good), (good, atmospher...
# 3058           0.0000  [(wait, hour), (hour, half), (half, tabl), (ta...
# 3059           0.8402  [(new, york), (york, style), (style, make), (m...
# 3060           0.7351  [(fun, place), (place, eat), (eat, food), (foo...
# 3061           0.6249  [(food, great), (great, ident), (ident, menu),...
#
#                                                Trigrams
# 0     [(may, sound, noisi), (sound, noisi, initi), (...
# 1     [(good, burger, atmospher), (burger, atmospher...
# 2     [(pre, arrang, breakfast), (arrang, breakfast,...
# 3     [(nice, decor, share), (decor, share, platter)...
# 4     [(great, hard, rock), (hard, rock, never), (ro...
# ...                                                 ...
# 3057  [(great, food, good), (food, good, atmospher),...
# 3058  [(wait, hour, half), (hour, half, tabl), (half...
# 3059  [(new, york, style), (york, style, make), (sty...
# 3060  [(fun, place, eat), (place, eat, food), (eat, ...
# 3061  [(food, great, ident), (great, ident, menu), (...
#
# [3062 rows x 7 columns]

# %%
trigrams_list = list(itertools.chain.from_iterable(hotel_df["Trigrams"]))
trigrams_freq = collections.Counter(trigrams_list)

trigrams_freq_DF = pd.DataFrame(trigrams_freq.most_common(40), columns=['Trigrams', 'Count'])
trigrams_freq_DF
# Out:
#                     Trigrams  Count
# 0         (hard, rock, cafe)    407
# 1        (visit, hard, rock)     79
# 2       (food, good, servic)     54
# 3       (servic, good, food)     53
# 4           (go, hard, rock)     52
# 5         (hard, rock, cafã)     52
# 6        (typic, hard, rock)     48
# 7       (locat, time, squar)     46
# 8       (great, food, great)     45
# 9         (good, food, good)     44
# 10     (food, great, servic)     40
# 11        (visit, new, york)     36
# 12  (food, great, atmospher)     35
# 13     (servic, great, food)     32
# 14        (love, hard, rock)     32
# 15      (expect, hard, rock)     31
# 16       (good, food, great)     30
# 17        (like, hard, rock)     30
# 18      (well, worth, visit)     30
# 19      (good, servic, good)     29
# 20     (food, reason, price)     27
# 21      (food, realli, good)     26
# 22         (new, york, citi)     26
# 23       (everi, hard, rock)     26
# 24        (mani, hard, rock)     24
# 25        (rock, cafe, food)     24
# 26        (best, hard, rock)     20
# 27         (rock, cafe, one)     20
# 28   (staff, friendli, food)     20
# 29      (right, time, squar)     20
# 30   (staff, friendli, help)     20
# 31      (visit, time, squar)     20
# 32      (heart, time, squar)     20
# 33      (time, squar, great)     20
# 34    (great, servic, great)     19
# 35      (great, locat, time)     18
# 36     (great, servic, food)     18
# 37        (rock, cafe, good)     18
# 38   (definit, worth, visit)     18
# 39      (hard, rock, experi)     18

# %%
plt.figure(figsize = (10,7))
sns.barplot(data = trigrams_freq_DF, x = "Count", y = "Trigrams")
plt.xlabel("Frequency")
plt.ylabel("Trigrams")
plt.title("40 Most Frequent Trigrams in TripAdvisore Reviews")
plt.show()

# %%
hotel_df[["Sentiment_TextBlob", "Sentiment_VADER"]].describe()
# Out:
#        Sentiment_TextBlob  Sentiment_VADER
# count         3062.000000      3062.000000
# mean             0.339853         0.639002
# std              0.266934         0.354576
# min             -1.000000        -0.933700
# 25%              0.175000         0.526700
# 50%              0.357143         0.771700
# 75%              0.519687         0.880700
# max              1.000000         0.980600

# %%
def sentiment_result(polarity):
    if polarity >= 0.1:
        return "Postive"
    elif polarity <= -0.1:
        return "Negative"
    else:
        return "Neutral"

# %%
hotel_df["Label"] = hotel_df["Sentiment_VADER"].apply(lambda x: sentiment_result(x))

# %%
hotel_df["Label"].value_counts()
# Out:
# Postive     2742
# Negative     173
# Neutral      147
# Name: Label, dtype: int64

# %%
hotel_df
# Out:
#                                                  Review  \
# 0     may sound noisi initi find good place bar nois...
# 1     good burger atmospher uniqu expect hard rock m...
# 2     pre arrang breakfast peopl open us normal open...
# 3     nice decor share platter crumb chicken spring ...
# 4     great hard rock never bad countri favourit far...
# ...                                                 ...
# 3057  great food good atmospher realli nice place su...
# 3058  wait hour half tabl sat cold room away main ro...
# 3059  new york style make hard rock best around worl...
# 3060  fun place eat food good seve quickli mani rock...
# 3061  food great ident menu everi locat server check...
#
#                                           Reviews_Token  \
# 0     [may, sound, noisi, initi, find, good, place, ...
# 1     [good, burger, atmospher, uniqu, expect, hard,...
# 2     [pre, arrang, breakfast, peopl, open, us, norm...
# 3     [nice, decor, share, platter, crumb, chicken, ...
# 4     [great, hard, rock, never, bad, countri, favou...
# ...                                                 ...
# 3057  [great, food, good, atmospher, realli, nice, p...
# 3058  [wait, hour, half, tabl, sat, cold, room, away...
# 3059  [new, york, style, make, hard, rock, best, aro...
# 3060  [fun, place, eat, food, good, seve, quickli, m...
# 3061  [food, great, ident, menu, everi, locat, serve...
#
#                                            Reviews_Lemm  Sentiment_TextBlob  \
# 0     [may, sound, noisi, initi, find, good, place, ...            0.441667
# 1     [good, burger, atmospher, uniqu, expect, hard,...            0.204167
# 2     [pre, arrang, breakfast, peopl, open, us, norm...            0.143723
# 3     [nice, decor, share, platter, crumb, chicken, ...            0.050000
# 4     [great, hard, rock, never, bad, countri, favou...            0.443056
# ...                                                 ...                 ...
# 3057  [great, food, good, atmospher, realli, nice, p...            0.700000
# 3058  [wait, hour, half, tabl, sit, cold, room, away...           -0.240000
# 3059  [new, york, style, make, hard, rock, best, aro...            0.388939
# 3060  [fun, place, eat, food, good, seve, quickli, m...            0.500000
# 3061  [food, great, ident, menu, everi, locat, serve...            0.450000
#
#       Sentiment_VADER                                            Bigrams  \
# 0              0.8720  [(may, sound), (sound, noisi), (noisi, initi),...
# 1              0.3612  [(good, burger), (burger, atmospher), (atmosph...
# 2              0.6808  [(pre, arrang), (arrang, breakfast), (breakfas...
# 3              0.8442  [(nice, decor), (decor, share), (share, platte...
# 4              0.9377  [(great, hard), (hard, rock), (rock, never), (...
# ...               ...                                                ...
# 3057           0.9136  [(great, food), (food, good), (good, atmospher...
# 3058           0.0000  [(wait, hour), (hour, half), (half, tabl), (ta...
# 3059           0.8402  [(new, york), (york, style), (style, make), (m...
# 3060           0.7351  [(fun, place), (place, eat), (eat, food), (foo...
# 3061           0.6249  [(food, great), (great, ident), (ident, menu),...
#
#                                                Trigrams    Label
# 0     [(may, sound, noisi), (sound, noisi, initi), (...  Postive
# 1     [(good, burger, atmospher), (burger, atmospher...  Postive
# 2     [(pre, arrang, breakfast), (arrang, breakfast,...  Postive
# 3     [(nice, decor, share), (decor, share, platter)...  Postive
# 4     [(great, hard, rock), (hard, rock, never), (ro...  Postive
# ...                                                 ...      ...
# 3057  [(great, food, good), (food, good, atmospher),...  Postive
# 3058  [(wait, hour, half), (hour, half, tabl), (half...  Neutral
# 3059  [(new, york, style), (york, style, make), (sty...  Postive
# 3060  [(fun, place, eat), (place, eat, food), (eat, ...  Postive
# 3061  [(food, great, ident), (great, ident, menu), (...  Postive
#
# [3062 rows x 8 columns]

# %%
data = hotel_df.to_csv(r'C:\\Users\\user\\Desktop\\Hotel_Review\\Review.csv',index=True)

cwd
# Out:
# 'C:\\Users\\user\\Desktop\\Hotel_Review'

# %%
data

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# 'C:\\Users\\user\\Desktop\\Hotel_Review'

# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv("Review.csv")

# %%
print("columns name\n\n",data.columns)
# Out:
# columns name
#
#  Index(['Unnamed: 0', 'Review', 'Reviews_Token', 'Reviews_Lemm',
#        'Sentiment_TextBlob', 'Sentiment_VADER', 'Bigrams', 'Trigrams',
#        'Label'],
#       dtype='object')

# %%
# dropping passed columns 
data.drop(['Unnamed: 0', 'Reviews_Token','Reviews_Lemm','Sentiment_TextBlob','Sentiment_VADER','Bigrams','Trigrams'], axis = 1, inplace = True)

# %%
data = pd.DataFrame(data)

# %%
data.head(3)
# Out:
#                                               Review    Label
# 0  may sound noisi initi find good place bar nois...  Postive
# 1  good burger atmospher uniqu expect hard rock m...  Postive
# 2  pre arrang breakfast peopl open us normal open...  Postive

# %%
data['Label'].unique
# Out:
# <bound method Series.unique of 0       Postive
# 1       Postive
# 2       Postive
# 3       Postive
# 4       Postive
#          ...
# 3057    Postive
# 3058    Neutral
# 3059    Postive
# 3060    Postive
# 3061    Postive
# Name: Label, Length: 3062, dtype: object>

# %%
data.to_csv(r'model.csv',index=False)
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Hotel_Review'
